# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

# %%
data = pd.read_csv('ecg.csv', header=None)
data.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
#
#         7         8         9    ...       131       132       133       134  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958  0.578621
# 1 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 2 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 3 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 4 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
#
#         135       136       137       138       139  140
# ...

# %%
def rate_hieusuat(lable, pred=None, xacsuat=None):
    confusion = confusion_matrix( lable, pred)
    accuracy = accuracy_score(lable , pred)
    precision = precision_score(lable , pred)
    recall = recall_score(lable , pred)
    f1 = f1_score(lable,pred)   
     
    roc_auc = roc_auc_score(lable, xacsuat)
    print('confusion matrix')
    print(confusion)

    # ROC-AUC print 
    print('accuracy: {0:.4f}, precision: {1:.4f}, recall: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    return confusion

# %%
data = pd.read_csv('ecg.csv', header=None)
raw = data.values
data.head().style.set_properties(**{'background-color': 'black', 'color': 'white', 'border-color': 'white'})
# Out:
# <style type="text/css">
# ...

# %%
# Lấy chiều dài của tín hiệu ECG
length = len(raw)

# Tạo một mảng chứa thời gian tương ứng với mỗi điểm dữ liệu
time = range(length)

# Vẽ biểu đồ waveform của tín hiệu ECG
plt.figure(figsize=(10, 5))
plt.plot(time, raw, color='blue')
plt.title('ECG Waveform')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
# Chọn hàng đầu tiên hoặc hàng bất kỳ từ dữ liệu
row_index = 1000  # Thay đổi chỉ số này để chọn hàng khác
selected_row = data.iloc[row_index, :]

# Tạo mảng thời gian tương ứng với mỗi điểm dữ liệu
time = range(len(selected_row))

# Vẽ biểu đồ waveform của hàng được chọn từ dữ liệu ECG
plt.figure(figsize=(10, 5))
plt.plot(time, selected_row, color='blue')
plt.title('ECG Waveform')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()
